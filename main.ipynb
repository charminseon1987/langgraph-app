# %%
from langgraph.graph import StateGraph, START, END
from typing_extensions import TypedDict
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langgrph.graph import StateGraph, START, END
#       2 from typing_extensions import TypedDict
#
# ModuleNotFoundError: No module named 'langgrph'

# %%
class State(TypedDict):
    hello: str

graph_builder = StateGraph(State)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class State(TypedDict):
#       2     hello : str
#       4 graph_builder = StateGraph(State)
#
# NameError: name 'TypedDict' is not defined

# %%
def node_one(state:State):
    print("node_one")

def node_two(state:State):
    print("node_two")

def node_three(state:State):
    print("node_three")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 def node_one(state:State):
#       2     print("node_one")
#       4 def node_two(state:State):
#
# NameError: name 'State' is not defined

# %%
graph_builder.add_node("node_one", node_one)
graph_builder.add_node("node_two", node_two)
