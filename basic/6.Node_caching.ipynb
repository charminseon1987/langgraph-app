# %%
from langgraph.graph import StateGraph, START, END
from typing_extensions import TypedDict
from typing import Annotated
from langgraph.cache.memory import InMemoryCache
from langgraph.types import CachePolicy
from datetime import datetime

# %%
class State(TypedDict):
    time :str

graph_builder=StateGraph(State)

# %%
def node_one(state:State):
    return{}


def node_two(state:State):
    return {
        "time" : f"{datetime.now()}"
    }

def node_three(state:State):
    return{}

# %%
graph_builder.add_node("node_one",node_one)
graph_builder.add_node(
    "node_two",
    node_two, 
    cache_policy = CachePolicy(ttl=20), #ttl=20 seconds
    )
graph_builder.add_node("node_three",node_three)

graph_builder.add_edge(START, "node_one")
graph_builder.add_edge("node_one","node_two")
graph_builder.add_edge("node_two","node_three")
graph_builder.add_edge("node_three",END)

# %%
import time
graph = graph_builder.compile(cache=InMemoryCache())

# graph.invoke({})
print(graph.invoke({}))
time.sleep(5)
print(graph.invoke({}))
time.sleep(5)
print(graph.invoke({}))
time.sleep(5)
print(graph.invoke({}))
time.sleep(5)
print(graph.invoke({}))
time.sleep(5)
# Out:
# {'time': '2026-03-12 16:50:10.887251'}
# {'time': '2026-03-12 16:50:10.887251'}
# {'time': '2026-03-12 16:50:10.887251'}
# {'time': '2026-03-12 16:50:10.887251'}
# {'time': '2026-03-12 16:50:30.896196'}
